# %%
# %run /Users/rathiady@gmail.com/utility_dev/adlsgen2_provisioning

# %%
storagename='irissapoc'
service_principal_id='51b7b1bd-472b-4602-b6f7-452cffa4628e'
service_principal_secret='aIj8Q~fROWsSm.~5ZEbT1VHHu.qdvtvosX-kWbE3'
tenantid='73bffe2b-9041-4754-aaf0-3ef61cde7559'
container='data-ingestion-poc'


authenticate_azure_adlsgen2_SP(storagename, service_principal_id, service_principal_secret, tenantid)

# %%
# %fs ls 'dbfs:/mnt/azure__data-ingestion-poc_irissapoc/source_files_misc/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
CustomerData_20220330_csv = spark.read.csv(path='dbfs:/mnt/azure__data-ingestion-poc_irissapoc/source_files_misc/CustomerData_20220330.csv', header= True, sep =',')
display(CustomerData_20220330_csv)
header_CustomerData_20220330_csv = CustomerData_20220330_csv.schema.names
print(header_CustomerData_20220330_csv)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
new_header_CustomerData_20220330_csv = [i.replace(' ','_') for i in header_CustomerData_20220330_csv]
print(new_header_CustomerData_20220330_csv)
# Out:
# ['Entity_UEN', 'Country_of_Risk', 'Country_of_Domicile', 'SIC_Canada', 'id', 'gender', 'birthdate', 'maiden_name', 'lname', 'fname', 'address', 'city', 'state', 'zip', 'primary_phone', 'primary_email', 'cc_type', 'Total_Assets_Amount', 'Total_Assets_Currency', 'Total_Sales_Amount', 'Total_Sales_Currency', 'SIN', 'Passport', 'Driving_ID']

# %%
CustomerData_20220330_csv = CustomerData_20220330_csv.toDF(*new_header_CustomerData_20220330_csv)
display(CustomerData_20220330_csv)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
